# %%
import classify_keras as ck
# !tensorboard --logdir='/Users/tc/crypto/tensorflowlog'
# Out:
# W0601 18:47:22.479450 123145386201088 plugin_event_accumulator.py:294] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0601 18:47:22.479954 123145386201088 plugin_event_accumulator.py:302] Found more than one metagraph event per run. Overwriting the metagraph with the newest event.
# W0601 18:47:22.504482 123145386201088 plugin_event_accumulator.py:294] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0601 18:47:22.505114 123145386201088 plugin_event_accumulator.py:302] Found more than one metagraph event per run. Overwriting the metagraph with the newest event.
# TensorBoard 1.13.1 at http://iMac.local:6006 (Press CTRL+C to quit)
# ...
